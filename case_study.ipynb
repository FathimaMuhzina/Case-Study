# %% [markdown]
# # Case study on Presentation of data

# %% [markdown]
# # 1. Read the dataset to the python environment.

# %%
import pandas as pd
cars_data=pd.read_csv(r'C:\Users\user\OneDrive\Desktop\Data Science\Week#4\cars_data.csv')

# %%
cars_data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # 2. Check for the null values present in the dataset.

# %%
cars_data.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # 3. Plot a bar graph of male vs female buyers participated in the sales.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(data=cars_data, x='Buyer Gender')
plt.title('Male Vs Female Buyers')
# Out:
# Text(0.5, 1.0, 'Male Vs Female Buyers')

# %% [markdown]
# # 4. Find the top 5 cars based on their sales price.

# %%
cars_data1=cars_data.sort_values(by=['Sale Price']).head(5)
cars_data1
# Out:
#          Make                 Model Nickname Car Gender Buyer Gender  \
# 3513      Geo               Tracker   Nowell       Male         Male
# 7234     Ford             Excursion   Patric       Male         Male
# 5956    Mazda                Mazda6   Milzie       Male       Female
# 6270   Nissan                 240SX   Paloma       Male       Female
# 6241  Lincoln  Continental Mark VII  Malissa     Female       Female
#
#       Buyer Age              Buzzword      Country        City  \
# 3513         64             impactful        Japan        Hagi
# 7234         30         Decentralized   Azerbaijan    Zaqatala
# 5956         39            motivating      Albania       Shezë
# 6270         48         Self-enabling  Philippines       Lanas
# 6241         57  budgetary management       Russia  Safakulevo
#
#       Dealer Latitude  Dealer Longitude      Color  New Car Purchase Date  \
# 3513        32.428624        130.649340     Orange     True    28/01/2016
# ...

# %% [markdown]
# # Just show the Make, Model and Sale Price

# %%
cars_data1[['Make','Model','Sale Price']]
# Out:
#          Make                 Model  Sale Price
# 3513      Geo               Tracker    10003.76
# 7234     Ford             Excursion    10019.95
# 5956    Mazda                Mazda6    10023.85
# 6270   Nissan                 240SX    10024.86
# 6241  Lincoln  Continental Mark VII    10039.82

# %% [markdown]
# # 5. Find the least 5 cars based on their Resell price.

# %%
cars_data2=cars_data.sort_values(by=['Resell Price']).head(5)
cars_data2
# Out:
#             Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 2446   Chevrolet         1500  Corenda       Male       Female         25
# 4933         GMC  Savana 1500     Lark     Female       Female         34
# 566       Jaguar           XF   Payton     Female         Male         64
# 2538  Mitsubishi       3000GT     Thia     Female       Female         25
# 5869    Infiniti          G37    Sonny       Male         Male         20
#
#             Buzzword      Country              City  Dealer Latitude  \
# 2446   collaboration  Philippines           Tubigan         8.490877
# 4933     interactive       Poland       Śródmieście        53.838651
# 566        Visionary      Nigeria       Ikot-Ekpene         5.174447
# 2538  well-modulated        China        Yanweigang        34.509325
# 5869      optimizing       France  Clermont-Ferrand        45.786764
#
#       Dealer Longitude      Color  New Car Purchase Date  Sale Price  \
# ...

# %% [markdown]
# # Just show the Make, Model and Resell Price

# %%
cars_data2[['Make','Model','Resell Price']]
# Out:
#             Make        Model  Resell Price
# 2446   Chevrolet         1500       2000.84
# 4933         GMC  Savana 1500       2005.44
# 566       Jaguar           XF       2014.09
# 2538  Mitsubishi       3000GT       2017.24
# 5869    Infiniti          G37       2017.83
